# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

sns.set(style="whitegrid")
pd.set_option('display.max_columns', None)

# %%
df_churn = pd.read_csv("synthetic_customer_churn_100k.csv")

# %%
# Fix: Updated countplot with proper hue assignment
plt.figure(figsize=(5,4))
sns.countplot(x='Churn', data=df_churn, hue='Churn', palette=['#06d6a0','#ef476f'], legend=False)
plt.title("Distribution of Churn")
plt.show()

# %%
# Updated boxplot calls with proper hue assignment
for col in numerical_cols:
  plt.figure(figsize=(6,4))
  sns.boxplot(x='Churn', y=col, data=df_churn, hue='Churn', palette=['#06d6a0', '#ef476f'], legend=False)
  plt.title(f"{col} vs Churn")
  plt.show()
